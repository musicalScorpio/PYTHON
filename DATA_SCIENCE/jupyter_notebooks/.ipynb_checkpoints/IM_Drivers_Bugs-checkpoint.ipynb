# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      |████████████████████████████████| 249 kB 2.9 MB/s
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/mukherjeeworldwide/Desktop/PERSONAL/CODING/PYTHON/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#Read it in a DataFrame
oo = pd.read_excel("../../DATA_SCIENCE/data_set/im/Delivered_Drivers_2022-2023.xlsx",skiprows=1)

# %%
oo.head(5)
# Out:
#   DriverName     Type PolarionID
# 0   inpdmsaa  Inquiry   IM-63470  \
# 1   diiqcbrq  Inquiry   IM-65235
# 2   sebphrsi  Inquiry   IM-67975
# 3   aghusqll  Inquiry   IM-69969
# 4   hampipei  Inquiry   IM-79002
#
#                                                Title    ResellerName
# 0  DDR - Inpeco DMS Automation to support aliquot...          Abbott  \
# 1  The QC Bracketing Driver needs to display the ...              DI
# 2  Add support for additional testcode/result com...  SEBIA Phoresis
# 3                                       NDR AGHU LIS            AGHU
# 4  hampipei - Update the driver to no longer use ...             NaN
#
#   CreatedDate ApprovedDate   StartDate DeliveryDate  ResolvedDate
# 0  2018-12-20   2022-06-09  2022-06-09   2022-06-30           NaN  \
# 1  2019-03-15   2022-08-09  2022-08-09   2022-08-16           NaN
# 2  2019-06-26   2022-05-16  2022-05-16   2022-05-16           NaN
# 3  2019-09-12   2020-03-31  2023-06-19   2023-09-22           NaN
# 4  2020-04-22   2020-04-30  2022-03-31   2022-04-22           NaN
#
#          Resolution VersionIntroduced
# 0               NaN               NaN
# 1               NaN               NaN
# 2               NaN               NaN
# 3  2023-09-22 15:30               NaN
# 4               NaN               NaN

# %%
oo.Type.value_counts()
# Out:
# Type
# Inquiry        255
# Known Issue     82
# Name: count, dtype: int64

# %%
oo = pd.read_excel("../../DATA_SCIENCE/jupyter_notebooks/output.xlsx",skiprows=1)

oo[['ApprovedDate','DeliveryDate']] = oo[['ApprovedDate','DeliveryDate']].apply(pd.to_datetime)
oo['NumberOfDays'] = (oo['DeliveryDate'] - oo['ApprovedDate'])


oo=oo[['DriverName','Type','CreatedDate','ApprovedDate','DeliveryDate', 'NumberOfDays','Title']]
#oo=oo.sort_values(by='NumberOfDays', ascending=False)

duplicates = oo[oo.duplicated('DriverName')]
oo=duplicates.sort_values(by=['DriverName', 'Type','CreatedDate'])
oo
#oo=oo[['DriverName','Type']].size()

#oo.to_csv('output1.csv')
#g= oo.groupby(['DriverName','Type']).agg({'DriverName':['count']})
#g.to_csv('output1.csv')
# Out:
#     DriverName         Type CreatedDate ApprovedDate DeliveryDate
# 1     abdalmpi      Inquiry  2023-09-01   2023-09-08   2023-10-04  \
# 4     abdicqii      Inquiry  2022-11-29   2023-03-28   2023-04-17
# 5     abdicqii      Inquiry  2023-04-24   2023-04-28   2023-06-23
# 6     abdicqii  Known Issue  2023-02-17          NaT   2023-03-30
# 9     abimulti      Inquiry  2023-09-25   2023-10-05   2023-12-22
# ..         ...          ...         ...          ...          ...
# 129   sysct90i      Inquiry  2023-08-11   2023-09-01   2023-09-01
# 130   sysct90i      Inquiry  2023-09-26   2023-10-12   2023-11-09
# 132   sysrouta      Inquiry  2022-08-31   2022-10-13   2022-11-28
# 133   sysrouta      Inquiry  2023-03-31   2023-06-13   2023-06-20
# 136   tcahl7aa  Known Issue  2023-08-24          NaT   2023-09-01
#
#     NumberOfDays                                              Title
# 1        26 days                  abdalmpi - enhancements requested
# 4        20 days           DDR abdicqii - parse control name for QC
# 5        56 days  DDR abdicqii - check for orders every second d...
# 6            NaT  abdicqii - Status messages are queued with no ...
# 9        78 days                DDR - abimulti Enhancement Requests
# ..           ...                                                ...
# 129       0 days     sysct90i - Additional changes for Healius pt.2
# 130      28 days  sysct90i - Additional changes for Healius - UI...
# 132      46 days               DDR sysrouta - STA.5 usable in Rules
# 133       7 days               DDR sysrouta - support aliquot order
# 136          NaT  Test priority takes over load balancing for in...
#
# [77 rows x 7 columns]

# %%
# Out:
# 0       21 days
# 1        7 days
# 2        0 days
# 3     1270 days
# 4      722 days
#          ...
# 332     14 days
# 333         NaT
# 334         NaT
# 335         NaT
# 336     19 days
# Name: C, Length: 337, dtype: timedelta64[ns]

# %%
g.size().unstack(['Type'], fill_value=0).plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 g.size().unstack(['Type'], fill_value=0).plot()
#
# TypeError: 'numpy.int64' object is not callable

# %%
oo = pd.read_excel("../../DATA_SCIENCE/jupyter_notebooks/output.xlsx",skiprows=1)

oo[['CreatedDate','ApprovedDate','DeliveryDate']] = oo[['CreatedDate','ApprovedDate','DeliveryDate']].apply(pd.to_datetime)
import numpy as np
oo['NumberOfDays'] = np.where (oo['Type'] == 'Known Issue', (oo['DeliveryDate'] - oo['CreatedDate']) ,(oo['DeliveryDate'] - oo['ApprovedDate'])) 

df1 = oo[oo['Type']=='Inquiry']
 

#copy into a new df
newdf = df1[['DriverName', 'NumberOfDays']].copy() 


newdf= newdf.head(10)
newdf
# Out:
#    DriverName NumberOfDays
# 0    abdalmpi       6 days
# 1    abdalmpi      26 days
# 2    abdgtwma       2 days
# 3    abdicqii      14 days
# 4    abdicqii      20 days
# 5    abdicqii      56 days
# 7    abdinfoi      18 days
# 8    abimulti      20 days
# 9    abimulti      78 days
# 12   bdcectri     108 days

# %%
df = newdf.head(10) 

import matplotlib.pyplot as plt

plt.bar(df['DriverName'], df['NumberOfDays'])

    

plt.xlabel('DriverName')
plt.ylabel('NumberOfDays')
plt.title('Drivers Build time') 

plt.show()

# %%
oo = pd.read_csv("../../DATA_SCIENCE/jupyter_notebooks/output.csv",skiprows=1)

#oo[['CreatedDate','ApprovedDate','DeliveryDate']] = oo[['CreatedDate','ApprovedDate','DeliveryDate']].apply(pd.to_datetime)
#import numpy as np
#oo['NumberOfDays'] = np.where (oo['Type'] == 'Known Issue', (oo['DeliveryDate'] - oo['CreatedDate']) ,(oo['DeliveryDate'] - oo['ApprovedDate'])) 

df1 = oo[oo['Type']=='Inquiry']
df2 = oo[oo['Type']=='Known Issue']
 

#copy into a new df
newdf_inquiry = df1[['DriverName', 'NumberOfDays']].copy() 
df_inquiry= newdf_inquiry.head(10)

newdf_KI = df2[['DriverName', 'NumberOfDays']].copy() 
df_KI= newdf_KI.head(5)

#=====
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(df_inquiry['DriverName'], df_inquiry['NumberOfDays'])
plt.show()

#=====

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(df_KI['DriverName'], df_KI['NumberOfDays'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/PERSONAL/CODING/PYTHON/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/Desktop/PERSONAL/CODING/PYTHON/venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Desktop/PERSONAL/CODING/PYTHON/venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 7
#       1 oo = pd.read_csv("../../DATA_SCIENCE/jupyter_notebooks/output.csv",skiprows=0)
#       3 #oo[['CreatedDate','ApprovedDate','DeliveryDate']] = oo[['CreatedDate','ApprovedDate','DeliveryDate']].apply(pd.to_datetime)
#       4 #import numpy as np
#       5 #oo['NumberOfDays'] = np.where (oo['Type'] == 'Known Issue', (oo['DeliveryDate'] - oo['CreatedDate']) ,(oo['DeliveryDate'] - oo['ApprovedDate']))
# ----> 7 df1 = oo[oo['Type']=='Inquiry']
#       8 df2 = oo[oo['Type']=='Known Issue']
#      11 #copy into a new df
#
# File ~/Desktop/PERSONAL/CODING/PYTHON/venv/lib/python3.9/site-packages/pandas/core/frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File ~/Desktop/PERSONAL/CODING/PYTHON/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'Type'

# %%
oo = pd.read_excel("../../DATA_SCIENCE/jupyter_notebooks/output.xlsx",skiprows=1)

#oo[['CreatedDate','ApprovedDate','DeliveryDate']] = oo[['CreatedDate','ApprovedDate','DeliveryDate']].apply(pd.to_datetime)
#import numpy as np

#oo['NumberOfDays'] = np.where (oo['Type'] == 'Known Issue', (oo['DeliveryDate'] - oo['CreatedDate']) ,(oo['DeliveryDate'] - oo['ApprovedDate']))

oo
#oo.to_excel('output.xlsx')
oo.to_csv('output.csv')
#df1 = oo[oo['Type']=='Inquiry' & oo['NumberOfDays'] > 30]

#df1.to_numpy()[0][5]
